# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon Jul 31 14:33:57 2023

@author: Lin
"""

import os
current_path = os.getcwd()
import numpy as np
from numpy import seterr
seterr(all='raise')
import matplotlib.pyplot as plt
import math
from tqdm import tqdm
import sys
sys.path.append(current_path)
sys.path.append(current_path+'/../../')
import myInput
import PACKAGE_MP_Linear as linear2d
sys.path.append(current_path+'/../calculate_tangent/')

# %%
def simple_magnitude(freqArray):
    xLim = [0, 360]
    binValue = 10.01
    binNum = round((abs(xLim[0])+abs(xLim[1]))/binValue)
    xCor = np.linspace((xLim[0]+binValue/2),(xLim[1]-binValue/2),binNum)

    freqArray_circle = np.ones(binNum)
    freqArray_circle = freqArray_circle/sum(freqArray_circle*binValue)

    magnitude_max = np.max(abs(freqArray - freqArray_circle))/np.average(freqArray_circle)
    magnitude_ave = np.average(abs(freqArray - freqArray_circle))/np.average(freqArray_circle)

    magnitude_stan = np.sqrt(np.sum((abs(freqArray - freqArray_circle)/np.average(freqArray_circle) - magnitude_ave)**2)/binNum)

    return magnitude_ave, magnitude_stan

    # coeff_high = abs(np.cos((xCor-90)/180*np.pi))
    # coeff_low = abs(np.cos((xCor)/180*np.pi))
    # return np.sum(freqArray * coeff_high)/np.sum(freqArray * coeff_low)

def find_fittingEllipse2(array): #failure
    K_mat = []
    Y_mat = []

    # Get the self-variable
    X = array[:,0]
    Y = array[:,1]

    K_mat = np.hstack([X**2, X*Y, Y**2, X, Y])
    Y_mat = np.ones_like(X)

    X_mat = np.linalg.lstsq(K_mat, Y_mat)[0].squeeze()
    # X_mat = (K_mat.T*K_mat).I * K_mat.T * Y_mat

    print('The ellipse is given by {0:.3}x^2 + {1:.3}xy+{2:.3}y^2+{3:.3}x+{4:.3}y = 1'.format(X_mat[0], X_mat[1], X_mat[2], X_mat[3], X_mat[4]))
    print(X_mat)

    return X_mat

def find_fittingEllipse3(array): 

    import cv2
    # Fit ellipse to the points
    ellipse = cv2.fitEllipse(array)
    # print(f"aspect ratio: {ellipse[1][0]/ellipse[1][1]}")

    return ellipse

def get_poly_center(micro_matrix, step):
    # Get the center of all non-periodic grains in matrix
    num_grains = int(np.max(micro_matrix[step,:]))
    center_list = np.zeros((num_grains,2))
    sites_num_list = np.zeros(num_grains)
    ave_radius_list = np.zeros(num_grains)
    coord_refer_i = np.zeros((micro_matrix.shape[1], micro_matrix.shape[2]))
    coord_refer_j = np.zeros((micro_matrix.shape[1], micro_matrix.shape[2]))
    for i in range(micro_matrix.shape[1]):
        for j in range(micro_matrix.shape[2]):
            coord_refer_i[i,j] = i
            coord_refer_j[i,j] = j

    table = micro_matrix[step,:,:,0]
    for i in range(num_grains):
        sites_num_list[i] = np.sum(table == i+1)

        if (sites_num_list[i] < 500) or \
           (np.max(coord_refer_i[table == i+1]) - np.min(coord_refer_i[table == i+1]) == micro_matrix.shape[1]) or \
           (np.max(coord_refer_j[table == i+1]) - np.min(coord_refer_j[table == i+1]) == micro_matrix.shape[2]): # grains on bc are ignored
          center_list[i, 0] = 0
          center_list[i, 1] = 0
          sites_num_list[i] == 0
        else:
          center_list[i, 0] = np.sum(coord_refer_i[table == i+1]) / sites_num_list[i]
          center_list[i, 1] = np.sum(coord_refer_j[table == i+1]) / sites_num_list[i]
    ave_radius_list = np.sqrt(sites_num_list / np.pi)

    return center_list, ave_radius_list

def get_poly_statistical_radius(micro_matrix, sites_list, step):
    # Get the max offset of average radius and real radius
    center_list, ave_radius_list = get_poly_center(micro_matrix, step)
    num_grains = int(np.max(micro_matrix[step,:]))

    max_radius_offset_list = np.zeros(num_grains)
    for n in range(num_grains):
        center = center_list[n]
        ave_radius = ave_radius_list[n]
        sites = sites_list[n]

        if ave_radius != 0:
          for sitei in sites:
              [i,j] = sitei
              current_radius = np.sqrt((i - center[0])**2 + (j - center[1])**2)
              radius_offset = abs(current_radius - ave_radius)
              if radius_offset > max_radius_offset_list[n]: max_radius_offset_list[n] = radius_offset

          max_radius_offset_list[n] = max_radius_offset_list[n] / ave_radius

    max_radius_offset = np.average(max_radius_offset_list[max_radius_offset_list!=0])
    area_list = np.pi*ave_radius_list*ave_radius_list
    if np.sum(area_list) == 0: max_radius_offset = 0
    else: max_radius_offset = np.sum(max_radius_offset_list * area_list) / np.sum(area_list)

    return max_radius_offset

def get_poly_statistical_ar(micro_matrix, step):
    # Get the average aspect ratio
    num_grains = int(np.max(micro_matrix[step,:]))
    sites_num_list = np.zeros(num_grains)
    coord_refer_i = np.zeros((micro_matrix.shape[1], micro_matrix.shape[2]))
    coord_refer_j = np.zeros((micro_matrix.shape[1], micro_matrix.shape[2]))
    for i in range(micro_matrix.shape[1]):
        for j in range(micro_matrix.shape[2]):
            coord_refer_i[i,j] = i
            coord_refer_j[i,j] = j

    aspect_ratio_i = np.zeros((num_grains,2))
    aspect_ratio_j = np.zeros((num_grains,2))
    aspect_ratio = np.zeros(num_grains)
    table = micro_matrix[step,:,:,0]

    aspect_ratio_i_list = [[] for _ in range(int(num_grains))]
    aspect_ratio_j_list = [[] for _ in range(int(num_grains))]
    for i in range(micro_matrix.shape[1]):
        for j in range(micro_matrix.shape[2]):
            grain_id = int(table[i][j]-1)
            sites_num_list[grain_id] +=1
            aspect_ratio_i_list[grain_id].append(coord_refer_i[i][j])
            aspect_ratio_j_list[grain_id].append(coord_refer_j[i][j])

    for i in range(num_grains):
        aspect_ratio_i[i, 0] = len(list(set(aspect_ratio_i_list[i])))
        aspect_ratio_j[i, 1] = len(list(set(aspect_ratio_j_list[i])))
        if aspect_ratio_j[i, 1] == 0: aspect_ratio[i] = 0
        else: aspect_ratio[i] = aspect_ratio_i[i, 0] / aspect_ratio_j[i, 1]

    # aspect_ratio = np.average(aspect_ratio[aspect_ratio!=0])
    aspect_ratio = np.sum(aspect_ratio * sites_num_list) / np.sum(sites_num_list)

    return aspect_ratio

def get_normal_vector(grain_structure_figure_one, grain_num):
    nx = grain_structure_figure_one.shape[0]
    ny = grain_structure_figure_one.shape[1]
    ng = np.max(grain_structure_figure_one)
    cores = 64
    loop_times = 5
    P0 = grain_structure_figure_one
    R = np.zeros((nx,ny,2))
    smooth_class = linear2d.linear_class(nx,ny,ng,cores,loop_times,P0,R)

    smooth_class.linear_main("inclination")
    P = smooth_class.get_P()
    # sites = smooth_class.get_gb_list(1)
    # print(len(sites))
    # for id in range(2,grain_num+1): sites += smooth_class.get_gb_list(id)
    # print(len(sites))
    sites = smooth_class.get_all_gb_list()
    sites_together = []
    for id in range(len(sites)): sites_together += sites[id]
    print("Total num of GB sites: " + str(len(sites_together)))

    return P, sites_together, sites

def get_normal_vector_slope(P, sites, step, para_name, bias=None):
    xLim = [0, 360]
    binValue = 10.01
    binNum = round((abs(xLim[0])+abs(xLim[1]))/binValue)
    xCor = np.linspace((xLim[0]+binValue/2),(xLim[1]-binValue/2),binNum)

    freqArray = np.zeros(binNum)
    degree = []
    for sitei in sites:
        [i,j] = sitei
        dx,dy = myInput.get_grad(P,i,j)
        degree.append(math.atan2(-dy, dx) + math.pi)
        # if dx == 0:
        #     degree.append(math.pi/2)
        # elif dy >= 0:
        #     degree.append(abs(math.atan(-dy/dx)))
        # elif dy < 0:
        #     degree.append(abs(math.atan(dy/dx)))
    for i in range(len(degree)):
        freqArray[int((degree[i]/math.pi*180-xLim[0])/binValue)] += 1
    freqArray = freqArray/sum(freqArray*binValue)

    if bias is not None:
        freqArray = freqArray + bias
        freqArray = freqArray/sum(freqArray*binValue)
    # Plot
    # plt.close()
    # fig = plt.figure(figsize=(5, 5))
    # ax = plt.gca(projection='polar')

    # ax.set_thetagrids(np.arange(0.0, 360.0, 20.0),fontsize=14)
    # ax.set_thetamin(0.0)
    # ax.set_thetamax(360.0)

    # ax.set_rgrids(np.arange(0, 0.008, 0.004))
    # ax.set_rlabel_position(0.0)  # 标签显示在0°
    # ax.set_rlim(0.0, 0.008)  # 标签范围为[0, 5000)
    # ax.set_yticklabels(['0', '0.004'],fontsize=14)

    # ax.grid(True, linestyle="-", color="k", linewidth=0.5, alpha=0.5)
    # ax.set_axisbelow('True')
    plt.plot(np.append(xCor,xCor[0])/180*math.pi, np.append(freqArray,freqArray[0]), linewidth=2, label=para_name)

    # fitting
    fit_coeff = np.polyfit(xCor, freqArray, 1)
    return freqArray

# %%
if __name__ == '__main__':
    # File name
    # npy_file_folder_iso = "/blue/michael.tonks/lin.yang/SPPARKS-VirtualIncEnergy/2d_poly_multiCoreCompare/results/"
    npy_file_folder = "/blue/michael.tonks/lin.yang/SPPARKS-VirtualIncEnergy/2d_poly_wellEnergy/results/"
    TJ_energy_type_070 = "0.7"
    TJ_energy_type_080 = "0.8"
    TJ_energy_type_090 = "0.9"

    # energy_function = "Cos"
    # energy_function = "Well"
    # energy_function = "CosMin1"
    energy_function = "CosMax1Mobility"
    npy_file_name_iso = "p_aveE_20000_Cos_delta0.0_J1_refer_1_0_0_seed56689_kt0.66.npy"
    npy_file_name_aniso_070 = f"p_aveE_20000_{energy_function}_delta{TJ_energy_type_070}_J1_refer_1_0_0_seed56689_kt0.66.npy"
    npy_file_name_aniso_080 = f"p_aveE_20000_{energy_function}_delta{TJ_energy_type_080}_J1_refer_1_0_0_seed56689_kt0.66.npy"
    npy_file_name_aniso_090 = f"p_aveE_20000_{energy_function}_delta{TJ_energy_type_090}_J1_refer_1_0_0_seed56689_kt0.66.npy"


    # Initial data
    npy_file_iso = np.load(npy_file_folder + npy_file_name_iso)
    npy_file_aniso_070 = np.load(npy_file_folder + npy_file_name_aniso_070)
    npy_file_aniso_080 = np.load(npy_file_folder + npy_file_name_aniso_080)
    npy_file_aniso_090 = np.load(npy_file_folder + npy_file_name_aniso_090)
    print(f"The 0.7 data size is: {npy_file_aniso_070.shape}")
    print(f"The 0.8 data size is: {npy_file_aniso_080.shape}")
    print(f"The 0.9 data size is: {npy_file_aniso_090.shape}")
    print(f"The iso data size is: {npy_file_iso.shape}")
    print("READING DATA DONE")

    # Initial container
    initial_grain_num = 20000
    step_num = npy_file_aniso_070.shape[0]
    grain_num_aniso_070 = np.zeros(npy_file_aniso_070.shape[0])
    grain_num_aniso_080 = np.zeros(npy_file_aniso_080.shape[0])
    grain_num_aniso_090 = np.zeros(npy_file_aniso_090.shape[0])
    grain_num_iso = np.zeros(npy_file_iso.shape[0])

    # Calculate the number of grains
    for i in range(npy_file_aniso_070.shape[0]):
        grain_num_aniso_070[i] = len(np.unique(npy_file_aniso_070[i,:].flatten()))
        grain_num_aniso_080[i] = len(np.unique(npy_file_aniso_080[i,:].flatten()))
        grain_num_iso[i] = len(np.unique(npy_file_iso[i,:].flatten()))
    for i in range(npy_file_aniso_090.shape[0]):
        grain_num_aniso_090[i] = len(np.unique(npy_file_aniso_090[i,:].flatten()))

    expected_grain_num = 1000
    special_step_distribution_070 = int(np.argmin(abs(grain_num_aniso_070 - expected_grain_num)))
    special_step_distribution_080 = int(np.argmin(abs(grain_num_aniso_080 - expected_grain_num)))
    special_step_distribution_090 = int(np.argmin(abs(grain_num_aniso_090 - expected_grain_num)))
    special_step_distribution_iso = int(np.argmin(abs(grain_num_iso - expected_grain_num)))
    print("Found time steps")
# Out:
# The 0.7 data size is: (201, 2400, 2400, 1)
# The 0.8 data size is: (201, 2400, 2400, 1)
# The 0.9 data size is: (201, 2400, 2400, 1)
# The iso data size is: (201, 2400, 2400, 1)
# READING DATA DONE
# Found time steps

# %%
    # Aniso - iso
    data_file_name_P = f'/well_normal_data/normal_distribution_iso_P_step{special_step_distribution_iso}.npy'
    data_file_name_sites = f'/well_normal_data/normal_distribution_iso_sites_step{special_step_distribution_iso}.npy'
    # if os.path.exists(current_path + data_file_name_P):
    #     P = np.load(current_path + data_file_name_P)
    #     sites = np.load(current_path + data_file_name_sites)
    # else:
    newplace = np.rot90(npy_file_iso[special_step_distribution_iso,:,:,:], 1, (0,1))
    P, sites, sites_list = get_normal_vector(newplace, initial_grain_num)
    np.save(current_path + data_file_name_P, P)
    np.save(current_path + data_file_name_sites, sites)

    slope_list = get_normal_vector_slope(P, sites, special_step_distribution_iso, "Iso")
    # For bias
    xLim = [0, 360]
    binValue = 10.01
    binNum = round((abs(xLim[0])+abs(xLim[1]))/binValue)
    freqArray_circle = np.ones(binNum)
    freqArray_circle = freqArray_circle/sum(freqArray_circle*binValue)
    slope_list_bias = freqArray_circle - slope_list


    # Start polar figure
    plt.close()
    fig = plt.figure(figsize=(5, 5))
    ax = plt.gca(projection='polar')

    ax.set_thetagrids(np.arange(0.0, 360.0, 45.0),fontsize=12)
    ax.set_thetamin(0.0)
    ax.set_thetamax(360.0)

    ax.set_rgrids(np.arange(0, 0.015, 0.004))
    ax.set_rlabel_position(0.0)  # 标签显示在0°
    ax.set_rlim(0.0, 0.015)  # 标签范围为[0, 5000)
    ax.set_yticklabels(['0', '4e-3', '8e-3', '1.2e-3'],fontsize=12)

    ax.grid(True, linestyle="-", color="k", linewidth=0.5, alpha=0.5)
    ax.set_axisbelow('True')

    # Get bias from kT test
    label_list = ["0.0", "0.7", "0.8", "0.9"]
    aniso_mag = np.zeros(len(label_list))
    aniso_mag_stand = np.zeros(len(label_list))
    aniso_rs = np.zeros(len(label_list))

    # Iso
    slope_list = get_normal_vector_slope(P, sites, special_step_distribution_iso, "Iso",slope_list_bias)
    as_list = []
    for n in range(len(sites_list)):
        if len(sites_list[n]) < 10: continue
        ellipse = find_fittingEllipse3(np.array(sites_list[n]))
        as_list.append(ellipse[1][0]/ellipse[1][1])
    aniso_rs[0] = np.average(as_list)
    print("iso done")

    # Aniso - 070
    data_file_name_P = f'/well_normal_data/normal_distribution_070_P_{energy_function}_step{special_step_distribution_070}.npy'
    data_file_name_sites = f'/well_normal_data/normal_distribution_070_sites_{energy_function}_step{special_step_distribution_070}.npy'
    # if os.path.exists(current_path + data_file_name_P):
    #     P = np.load(current_path + data_file_name_P)
    #     sites = np.load(current_path + data_file_name_sites)
    # else:
    newplace = np.rot90(npy_file_aniso_070[special_step_distribution_070,:,:,:], 1, (0,1))
    P, sites, sites_list = get_normal_vector(newplace, initial_grain_num)
    np.save(current_path + data_file_name_P, P)
    np.save(current_path + data_file_name_sites, sites)

    slope_list = get_normal_vector_slope(P, sites, special_step_distribution_070, r"$\sigma$=0.7",slope_list_bias)
    as_list = []
    for n in range(len(sites_list)):
        if len(sites_list[n]) < 10: continue
        ellipse = find_fittingEllipse3(np.array(sites_list[n]))
        as_list.append(ellipse[1][0]/ellipse[1][1])
    aniso_rs[1] = np.average(as_list)
    print("070 done")

    # Aniso - 0.8
    data_file_name_P = f'/well_normal_data/normal_distribution_080_P_{energy_function}_step{special_step_distribution_080}.npy'
    data_file_name_sites = f'/well_normal_data/normal_distribution_080_sites_{energy_function}_step{special_step_distribution_080}.npy'
    # if os.path.exists(current_path + data_file_name_P):
    #     P = np.load(current_path + data_file_name_P)
    #     sites = np.load(current_path + data_file_name_sites)
    # else:
    newplace = np.rot90(npy_file_aniso_080[special_step_distribution_080,:,:,:], 1, (0,1))
    P, sites, sites_list = get_normal_vector(newplace, initial_grain_num)
    np.save(current_path + data_file_name_P, P)
    np.save(current_path + data_file_name_sites, sites)

    slope_list = get_normal_vector_slope(P, sites, special_step_distribution_080, r"$\sigma$=0.8",slope_list_bias)
    as_list = []
    for n in range(len(sites_list)):
        if len(sites_list[n]) < 10: continue
        ellipse = find_fittingEllipse3(np.array(sites_list[n]))
        as_list.append(ellipse[1][0]/ellipse[1][1])
    aniso_rs[2] = np.average(as_list)
    print("080 done")

    # Aniso - 090
    data_file_name_P = f'/well_normal_data/normal_distribution_090_P_{energy_function}_step{special_step_distribution_090}.npy'
    data_file_name_sites = f'/well_normal_data/normal_distribution_090_sites_{energy_function}_step{special_step_distribution_090}.npy'
    # if os.path.exists(current_path + data_file_name_P):
    #     P = np.load(current_path + data_file_name_P)
    #     sites = np.load(current_path + data_file_name_sites)
    # else:
    newplace = np.rot90(npy_file_aniso_090[special_step_distribution_090,:,:,:], 1, (0,1))
    P, sites, sites_list = get_normal_vector(newplace, initial_grain_num)
    np.save(current_path + data_file_name_P, P)
    np.save(current_path + data_file_name_sites, sites)

    slope_list = get_normal_vector_slope(P, sites, special_step_distribution_090, r"$\sigma$=0.9",slope_list_bias)
    as_list = []
    for n in range(len(sites_list)):
        if len(sites_list[n]) < 10: continue
        ellipse = find_fittingEllipse3(np.array(sites_list[n]))
        as_list.append(ellipse[1][0]/ellipse[1][1])
    aniso_rs[3] = np.average(as_list)
    print("090 done")
    

    plt.legend(loc=(-0.12,-0.35),fontsize=16,ncol=3)
    plt.savefig(current_path + f"/figures/normal_distribution_poly_20k_after_removing_bias_{energy_function}_{expected_grain_num}grains.png", dpi=400,bbox_inches='tight')

    plt.close()
    fig = plt.figure(figsize=(5, 5))
    plt.plot(np.linspace(0,len(label_list)-1,len(label_list)), aniso_rs, '.-', markersize=8, linewidth=2)
    plt.xlabel(r"$\sigma$", fontsize=16)
    plt.ylabel("Aspect Ratio", fontsize=16)
    plt.xticks(np.linspace(0,len(label_list)-1,len(label_list)),label_list)
    # plt.legend(fontsize=16)
    plt.ylim([-0.05,1.0])
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    plt.savefig(current_path + f"/figures/anisotropic_poly_p_20k_aspect_ratio_{energy_function}_{expected_grain_num}grains.png", dpi=400,bbox_inches='tight')

    # save the aspect ratio data for future plot
    ar_data_path = f"/well_normal_data/aspect_ratio_{energy_function}_grain{expected_grain_num}.npy"
    np.save(current_path+ar_data_path, aniso_rs)
# Out:
# the processor [0, 0] start...
# the processor [0, 1] start...
# the processor [0, 2] start...
# process[0, 0] read 0 times and max qsize 0
# my core time is 0.96711
# the processor [0, 3] start...
# process[0, 1] read 0 times and max qsize 0res_back start...
# my res time is 0.046436
#
# my core time is 0.979009
# the processor [0, 4] start...
# process[0, 2] read 0 times and max qsize 0res_back start...
# my res time is 0.013784
#
# my core time is 1.002531
# the processor [0, 5] start...
# process[0, 3] read 0 times and max qsize 0
# my core time is 0.907386
# res_back start...
# my res time is 0.017066
# the processor [0, 6] start...
# process[0, 4] read 0 times and max qsize 0
# my core time is 0.931368
# res_back start...
# my res time is 0.017453
# res_back start...
# process[0, 5] read 0 times and max qsize 0
# my core time is 0.96582
# the processor [0, 7] start...
# my res time is 0.239994
# res_back start...
# my res time is 0.013164
# the processor [1, 0] start...
# process[0, 6] read 0 times and max qsize 0
# my core time is 1.023989
# process[0, 7] read 0 times and max qsize 0
# my core time is 0.859122
# the processor [1, 1] start...
# res_back start...
# my res time is 0.016814
# res_back start...
# my res time is 0.016226
# process[1, 0] read 0 times and max qsize 0
# my core time is 0.93794
# the processor [1, 2] start...
# the processor [1, 3] start...
# process[1, 1] read 0 times and max qsize 0
# my core time is 0.896357
# res_back start...
# my res time is 0.212295
# the processor [1, 4] start...
# process[1, 2] read 0 times and max qsize 0
# my core time is 0.936685
# res_back start...
# my res time is 0.016267
# the processor [1, 5] start...
# process[1, 3] read 0 times and max qsize 0
# my core time is 0.967715
# res_back start...
# my res time is 0.017591
# the processor [1, 6] start...
# process[1, 4] read 0 times and max qsize 0
# my core time is 0.944291
# res_back start...
# my res time is 0.017923
# res_back start...
# process[1, 5] read 0 times and max qsize 0
# my core time is 0.871248
# the processor [1, 7] start...
# my res time is 0.208865
# res_back start...
# the processor [2, 0] start...
# process[1, 6] read 0 times and max qsize 0
# my core time is 1.02797
# my res time is 0.024271
# the processor [2, 1] start...
# process[1, 7] read 0 times and max qsize 0
# my core time is 0.914721
# res_back start...
# my res time is 0.016114
# process[2, 0] read 0 times and max qsize 0
# my core time is 0.919181
# the processor [2, 2] start...
# res_back start...
# my res time is 0.01676
# res_back start...
# my res time is 0.016759
# the processor [2, 3] start...
# process[2, 1] read 0 times and max qsize 0
# my core time is 1.005885
# the processor [2, 4] start...
# process[2, 2] read 0 times and max qsize 0
# my core time is 0.932453
# res_back start...
# my res time is 0.018034
# res_back start...
# my res time is 0.015204
# the processor [2, 5] start...
# process[2, 3] read 0 times and max qsize 0
# my core time is 1.11567
# process[2, 4] read 0 times and max qsize 0
# my core time is 0.869954
# the processor [2, 6] start...
# res_back start...
# my res time is 0.016219
# res_back start...
# my res time is 0.015556
# process[2, 5] read 0 times and max qsize 0
# my core time is 0.936626
# the processor [2, 7] start...
# res_back start...
# my res time is 0.015377
# process[2, 6] read 0 times and max qsize 0
# my core time is 0.937145
# the processor [3, 0] start...
# res_back start...
# my res time is 0.016823
# process[2, 7] read 0 times and max qsize 0
# my core time is 0.995329
# the processor [3, 1] start...
# process[3, 0] read 0 times and max qsize 0res_back start...
# my res time is 0.016054
#
# my core time is 0.866432
# the processor [3, 2] start...
# res_back start...
# my res time is 0.015806
# process[3, 1] read 0 times and max qsize 0
# my core time is 0.982186
# the processor [3, 3] start...
# res_back start...
# my res time is 0.01514
# the processor [3, 4] start...
# process[3, 2] read 0 times and max qsize 0
# my core time is 1.046424
# process[3, 3] read 0 times and max qsize 0res_back start...
# my res time is 0.016569
#
# my core time is 0.914857
# the processor [3, 5] start...
# res_back start...
# my res time is 0.016736
# process[3, 4] read 0 times and max qsize 0
# my core time is 0.967731
# the processor [3, 6] start...
# res_back start...
# my res time is 0.016718
# process[3, 5] read 0 times and max qsize 0
# my core time is 0.944176
# the processor [3, 7] start...
# res_back start...
# my res time is 0.01648
# process[3, 6] read 0 times and max qsize 0
# my core time is 0.943152
# the processor [4, 0] start...
# res_back start...
# my res time is 0.221143
# the processor [4, 1] start...
# process[3, 7] read 0 times and max qsize 0
# my core time is 0.984149
# process[4, 0] read 0 times and max qsize 0
# my core time is 0.911588
# the processor [4, 2] start...
# res_back start...
# my res time is 0.016654
# res_back start...
# my res time is 0.016291
# process[4, 1] read 0 times and max qsize 0
# my core time is 0.90424
# the processor [4, 3] start...
# res_back start...
# my res time is 0.01573
# process[4, 2] read 0 times and max qsize 0
# my core time is 0.933753
# the processor [4, 4] start...
# res_back start...
# my res time is 0.017747
# process[4, 3] read 0 times and max qsize 0
# my core time is 0.917245
# the processor [4, 5] start...
# res_back start...
# my res time is 0.016008
# the processor [4, 6] start...
# process[4, 4] read 0 times and max qsize 0
# my core time is 0.9991
# the processor [4, 7] start...
# process[4, 5] read 0 times and max qsize 0
# my core time is 0.997037
# res_back start...
# my res time is 0.016246
# res_back start...
# the processor [5, 0] start...
# process[4, 6] read 0 times and max qsize 0
# my core time is 0.98288
# my res time is 0.233977
# the processor [5, 1] start...
# process[4, 7] read 0 times and max qsize 0
# my core time is 0.985306
# res_back start...
# my res time is 0.01786
# res_back start...
# process[5, 0] read 0 times and max qsize 0
# my core time is 0.813727
# the processor [5, 2] start...
# my res time is 0.032054
# res_back start...
# my res time is 0.016111
# the processor [5, 3] start...
# process[5, 1] read 0 times and max qsize 0
# my core time is 0.978082
# the processor [5, 4] start...
# process[5, 2] read 0 times and max qsize 0
# my core time is 1.01273
# res_back start...
# my res time is 0.017217
# the processor [5, 5] start...
# process[5, 3] read 0 times and max qsize 0
# my core time is 0.922452
# res_back start...
# my res time is 0.018203
# res_back start...
# my res time is 0.017122
# process[5, 4] read 0 times and max qsize 0
# my core time is 0.973339
# the processor [5, 6] start...
# res_back start...
# my res time is 0.015229
# process[5, 5] read 0 times and max qsize 0
# my core time is 0.927688
# the processor [5, 7] start...
# res_back start...
# my res time is 0.015632
# process[5, 6] read 0 times and max qsize 0
# my core time is 0.865321
# the processor [6, 0] start...
# the processor [6, 1] start...
# process[5, 7] read 0 times and max qsize 0
# my core time is 0.934041
# res_back start...
# my res time is 0.01575
# the processor [6, 2] start...
# process[6, 0] read 0 times and max qsize 0
# my core time is 0.968508
# res_back start...
# my res time is 0.016632
# the processor [6, 3] start...
# process[6, 1] read 0 times and max qsize 0
# my core time is 0.973374
# res_back start...
# my res time is 0.015591
# the processor [6, 4] start...
# process[6, 2] read 0 times and max qsize 0
# my core time is 0.989188
# res_back start...
# my res time is 0.01619
# res_back start...
# the processor [6, 5] start...
# process[6, 3] read 0 times and max qsize 0
# my core time is 1.001325
# my res time is 0.240003
# res_back start...
# process[6, 4] read 0 times and max qsize 0
# my core time is 0.887266
# the processor [6, 6] start...
# my res time is 0.028593
# res_back start...
# my res time is 0.015347
# the processor [6, 7] start...
# process[6, 5] read 0 times and max qsize 0
# my core time is 0.991206
# process[6, 6] read 0 times and max qsize 0
# my core time is 0.820478
# the processor [7, 0] start...
# res_back start...
# my res time is 0.015957
# res_back start...
# my res time is 0.016153
# process[6, 7] read 0 times and max qsize 0
# my core time is 0.927117
# the processor [7, 1] start...
# res_back start...
# my res time is 0.013221
# process[7, 0] read 0 times and max qsize 0
# my core time is 0.920322
# the processor [7, 2] start...
# the processor [7, 3] start...
# process[7, 1] read 0 times and max qsize 0
# my core time is 0.966043
# res_back start...
# my res time is 0.017381
# the processor [7, 4] start...
# process[7, 2] read 0 times and max qsize 0
# my core time is 0.971891
# res_back start...
# my res time is 0.015909
# the processor [7, 5] start...
# process[7, 3] read 0 times and max qsize 0
# my core time is 1.015746
# res_back start...
# my res time is 0.015956
# the processor [7, 6] start...
# process[7, 4] read 0 times and max qsize 0
# my core time is 0.929918
# res_back start...
# my res time is 0.016828
# res_back start...
# my res time is 0.032236
# the processor [7, 7] start...
# process[7, 5] read 0 times and max qsize 0
# my core time is 1.027684
# process[7, 6] read 0 times and max qsize 0
# my core time is 0.943329
# res_back start...
# my res time is 0.015655
# res_back start...
# my res time is 0.015555
# process[7, 7] read 0 times and max qsize 0
# my core time is 1.005737
# res_back start...
# my res time is 0.017369
# core done!
# Total num of GB sites: 243048
# /scratch/local/32893972/ipykernel_2560132/984173300.py:26: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = plt.gca(projection='polar')
# iso done
# the processor [0, 0] start...
# the processor [0, 1] start...
# process[0, 0] read 0 times and max qsize 0
# my core time is 0.89209
# the processor [0, 2] start...
# res_back start...
# the processor [0, 3] start...
# process[0, 1] read 0 times and max qsize 0
# my core time is 1.029895
# my res time is 0.28369
# process[0, 2] read 0 times and max qsize 0
# my core time is 0.936345
# the processor [0, 4] start...
# res_back start...
# my res time is 0.014239
# res_back start...
# my res time is 0.014025
# process[0, 3] read 0 times and max qsize 0
# my core time is 0.969429
# the processor [0, 5] start...
# res_back start...
# my res time is 0.017403
# the processor [0, 6] start...
# process[0, 4] read 0 times and max qsize 0
# my core time is 1.018242
# the processor [0, 7] start...
# process[0, 5] read 0 times and max qsize 0
# my core time is 1.006556
# res_back start...
# my res time is 0.241654
# the processor [1, 0] start...
# process[0, 6] read 0 times and max qsize 0
# my core time is 1.063234
# res_back start...
# my res time is 0.228567
# process[0, 7] read 0 times and max qsize 0
# my core time is 0.893527
# the processor [1, 1] start...
# res_back start...
# my res time is 0.249121
# res_back start...
# my res time is 0.016235
# process[1, 0] read 0 times and max qsize 0
# my core time is 0.905521
# the processor [1, 2] start...
# res_back start...
# my res time is 0.016725
# the processor [1, 3] start...
# process[1, 1] read 0 times and max qsize 0
# my core time is 0.944624
# the processor [1, 4] start...
# process[1, 2] read 0 times and max qsize 0
# my core time is 1.041317
# res_back start...
# my res time is 0.017051
# process[1, 3] read 0 times and max qsize 0
# my core time is 0.893656
# the processor [1, 5] start...
# res_back start...
# my res time is 0.016745
# process[1, 4] read 0 times and max qsize 0
# my core time is 0.891651
# the processor [1, 6] start...
# res_back start...
# my res time is 0.017222
# res_back start...
# my res time is 0.014617
# the processor [1, 7] start...
# process[1, 5] read 0 times and max qsize 0
# my core time is 0.954107
# the processor [2, 0] start...
# process[1, 6] read 0 times and max qsize 0
# my core time is 0.965913
# res_back start...
# my res time is 0.017823
# the processor [2, 1] start...
# process[1, 7] read 0 times and max qsize 0
# my core time is 0.930564
# res_back start...
# my res time is 0.015838
# res_back start...
# process[2, 0] read 0 times and max qsize 0
# my core time is 0.844544
# the processor [2, 2] start...
# my res time is 0.226333
# res_back start...
# my res time is 0.01519
# the processor [2, 3] start...
# process[2, 1] read 0 times and max qsize 0
# my core time is 0.946729
# the processor [2, 4] start...
# process[2, 2] read 0 times and max qsize 0
# my core time is 0.948066
# res_back start...
# my res time is 0.243716
# the processor [2, 5] start...
# process[2, 3] read 0 times and max qsize 0
# my core time is 1.031982
# res_back start...
# my res time is 0.240942
# the processor [2, 6] start...
# process[2, 4] read 0 times and max qsize 0
# my core time is 1.032432
# res_back start...
# my res time is 0.015059
# process[2, 5] read 0 times and max qsize 0
# my core time is 0.782777
# the processor [2, 7] start...
# res_back start...
# my res time is 0.238185
# res_back start...
# my res time is 0.015274
# the processor [3, 0] start...
# process[2, 6] read 0 times and max qsize 0
# my core time is 1.016064
# the processor [3, 1] start...
# process[2, 7] read 0 times and max qsize 0
# my core time is 0.917649
# res_back start...
# my res time is 0.01647
# process[3, 0] read 0 times and max qsize 0
# my core time is 0.950504
# the processor [3, 2] start...
# res_back start...
# my res time is 0.014868
# process[3, 1] read 0 times and max qsize 0res_back start...
# my res time is 0.249527
#
# my core time is 0.919003
# the processor [3, 3] start...
# res_back start...
# my res time is 0.015327
# the processor [3, 4] start...
# process[3, 2] read 0 times and max qsize 0
# my core time is 1.036729
# the processor [3, 5] start...
# process[3, 3] read 0 times and max qsize 0
# my core time is 0.996884
# res_back start...
# my res time is 0.015087
# the processor [3, 6] start...
# process[3, 4] read 0 times and max qsize 0
#
# my core time is 0.933472res_back start...
# my res time is 0.015471
# res_back start...
# my res time is 0.030412
# process[3, 5] read 0 times and max qsize 0
# my core time is 0.940052
# the processor [3, 7] start...
# res_back start...
# my res time is 0.015213
# the processor [4, 0] start...
# process[3, 6] read 0 times and max qsize 0
# my core time is 0.98789
# the processor [4, 1] start...
# process[3, 7] read 0 times and max qsize 0
# my core time is 1.014466
# res_back start...
# my res time is 0.014392
# the processor [4, 2] start...
# process[4, 0] read 0 times and max qsize 0
# my core time is 0.921318
# res_back start...
# my res time is 0.013926
# the processor [4, 3] start...
# process[4, 1] read 0 times and max qsize 0
# my core time is 0.970547
# res_back start...
# my res time is 0.0147
# process[4, 2] read 0 times and max qsize 0
# my core time is 0.880109
# the processor [4, 4] start...
# res_back start...
# my res time is 0.016178
# res_back start...
# my res time is 0.014764
# the processor [4, 5] start...
# process[4, 3] read 0 times and max qsize 0
# my core time is 0.906775
# the processor [4, 6] start...
# process[4, 4] read 0 times and max qsize 0
# my core time is 0.965026
# res_back start...
# my res time is 0.016227
# the processor [4, 7] start...
# process[4, 5] read 0 times and max qsize 0
# my core time is 0.943121
# res_back start...
# my res time is 0.017537
# res_back start...
# my res time is 0.016688the processor [5, 0] start...
# process[4, 6] read 0 times and max qsize 0
# my core time is 0.960526
#
# process[4, 7] read 0 times and max qsize 0
# my core time is 0.855538
# the processor [5, 1] start...
# res_back start...
# my res time is 0.015719
# res_back start...
# my res time is 0.014784
# the processor [5, 2] start...
# process[5, 0] read 0 times and max qsize 0
# my core time is 0.971721
# the processor [5, 3] start...
# process[5, 1] read 0 times and max qsize 0
# my core time is 1.001509
# res_back start...
# my res time is 0.017297
# res_back start...
# my res time is 0.249494
# the processor [5, 4] start...
# process[5, 2] read 0 times and max qsize 0
# my core time is 1.034668
# process[5, 3] read 0 times and max qsize 0
# my core time is 0.955468
# the processor [5, 5] start...
# res_back start...
# my res time is 0.017355
# res_back start...
# my res time is 0.015006
# the processor [5, 6] start...
# process[5, 4] read 0 times and max qsize 0
# my core time is 0.974681
# the processor [5, 7] start...
# process[5, 5] read 0 times and max qsize 0
# res_back start...
# my res time is 0.015403
# my core time is 1.074019
# the processor [6, 0] start...
# process[5, 6] read 0 times and max qsize 0
# my core time is 0.897736
# res_back start...
# my res time is 0.015486
# the processor [6, 1] start...
# process[5, 7] read 0 times and max qsize 0
# my core time is 0.970114
# res_back start...
# my res time is 0.015363
# the processor [6, 2] start...
# process[6, 0] read 0 times and max qsize 0
# my core time is 1.054624
# res_back start...
# my res time is 0.014164
# the processor [6, 3] start...
# process[6, 1] read 0 times and max qsize 0
# my core time is 1.020349
# res_back start...
# my res time is 0.014001
# process[6, 2] read 0 times and max qsize 0
# my core time is 0.925965
# the processor [6, 4] start...
# res_back start...
# my res time is 0.014508
# res_back start...
# my res time is 0.013754
# the processor [6, 5] start...
# process[6, 3] read 0 times and max qsize 0
# my core time is 0.992667
# the processor [6, 6] start...
# process[6, 4] read 0 times and max qsize 0
# my core time is 0.968986
# res_back start...
# my res time is 0.01596
# process[6, 5] read 0 times and max qsize 0
# my core time is 0.905929
# the processor [6, 7] start...
# res_back start...
# my res time is 0.01813
# res_back start...
# my res time is 0.016755
# the processor [7, 0] start...
# process[6, 6] read 0 times and max qsize 0
# my core time is 0.967661
# the processor [7, 1] start...
# process[6, 7] read 0 times and max qsize 0
# my core time is 0.928655
# res_back start...
# my res time is 0.017973
# res_back start...
# my res time is 0.016013
# process[7, 0] read 0 times and max qsize 0
# my core time is 0.928943
# the processor [7, 2] start...
# process[7, 1] read 0 times and max qsize 0res_back start...
# my res time is 0.015934
#
# my core time is 0.864158
# the processor [7, 3] start...
# res_back start...
# my res time is 0.015233
# the processor [7, 4] start...
# process[7, 2] read 0 times and max qsize 0
# my core time is 0.998629
# the processor [7, 5] start...
# process[7, 3] read 0 times and max qsize 0
# my core time is 1.007753
# res_back start...
# my res time is 0.015048
# process[7, 4] read 0 times and max qsize 0
# my core time is 0.900454
# the processor [7, 6] start...
# res_back start...
# my res time is 0.015486
# res_back start...
# my res time is 0.015048
# the processor [7, 7] start...
# process[7, 5] read 0 times and max qsize 0
# my core time is 1.024484
# process[7, 6] read 0 times and max qsize 0
# my core time is 0.872123
# res_back start...
# my res time is 0.014804
# res_back start...
# my res time is 0.013234
# process[7, 7] read 0 times and max qsize 0
# my core time is 0.953173
# res_back start...
# my res time is 0.014026
# core done!
# Total num of GB sites: 245635
# 070 done
# the processor [0, 0] start...
# the processor [0, 1] start...
# the processor [0, 2] start...
# process[0, 0] read 0 times and max qsize 0
# my core time is 0.960234
# the processor [0, 3] start...
# process[0, 1] read 0 times and max qsize 0
# res_back start...
# my res time is 0.062142
# my core time is 0.917119
# the processor [0, 4] start...
# process[0, 2] read 0 times and max qsize 0res_back start...
# my res time is 0.014412
#
# my core time is 1.003755
# process[0, 3] read 0 times and max qsize 0
# my core time is 0.805556
# the processor [0, 5] start...
# res_back start...
# my res time is 0.014331
# the processor [0, 6] start...
# process[0, 4] read 0 times and max qsize 0
# my core time is 0.969792
# res_back start...
# my res time is 0.014957
# the processor [0, 7] start...
# process[0, 5] read 0 times and max qsize 0
# my core time is 0.910954
# res_back start...
# my res time is 0.014644
# res_back start...
# the processor [1, 0] start...
# process[0, 6] read 0 times and max qsize 0
# my core time is 1.008367
# my res time is 0.207169
# the processor [1, 1] start...
# process[0, 7] read 0 times and max qsize 0
# my core time is 0.910089
# res_back start...
# my res time is 0.013156
# the processor [1, 2] start...
# process[1, 0] read 0 times and max qsize 0
# my core time is 0.968803
# res_back start...
# my res time is 0.014379
# the processor [1, 3] start...
# process[1, 1] read 0 times and max qsize 0
# my core time is 0.964039
# res_back start...
# my res time is 0.015077
# res_back start...
# my res time is 0.013665
# process[1, 2] read 0 times and max qsize 0
# my core time is 0.91542
# the processor [1, 4] start...
# res_back start...
# my res time is 0.015301
# process[1, 3] read 0 times and max qsize 0
# my core time is 0.957673
# the processor [1, 5] start...
# process[1, 4] read 0 times and max qsize 0
# my core time is 0.861597
# the processor [1, 6] start...
# res_back start...
# my res time is 0.223086
# res_back start...
# my res time is 0.014736
# process[1, 5] read 0 times and max qsize 0
# my core time is 0.877159
# the processor [1, 7] start...
# res_back start...
# my res time is 0.015462
# the processor [2, 0] start...
# process[1, 6] read 0 times and max qsize 0
# my core time is 0.913705
# the processor [2, 1] start...
# process[1, 7] read 0 times and max qsize 0
# my core time is 0.998902
# res_back start...
# my res time is 0.014253
# process[2, 0] read 0 times and max qsize 0
# my core time is 0.894492
# the processor [2, 2] start...
# res_back start...
# my res time is 0.014637
# res_back start...
# my res time is 0.015275
# the processor [2, 3] start...
# process[2, 1] read 0 times and max qsize 0
# my core time is 1.023613
# process[2, 2] read 0 times and max qsize 0
# my core time is 0.921037
# the processor [2, 4] start...
# res_back start...
# my res time is 0.015155
# res_back start...
# my res time is 0.014852
# process[2, 3] read 0 times and max qsize 0
# my core time is 0.977715
# the processor [2, 5] start...
# res_back start...
# my res time is 0.226259
# the processor [2, 6] start...
# process[2, 4] read 0 times and max qsize 0
# my core time is 0.974028
# the processor [2, 7] start...
# process[2, 5] read 0 times and max qsize 0
# my core time is 0.987607
# res_back start...
# my res time is 0.014704
# the processor [3, 0] start...
# process[2, 6] read 0 times and max qsize 0
# my core time is 0.955081
# res_back start...
# my res time is 0.017453
# res_back start...
# my res time is 0.014695
# process[2, 7] read 0 times and max qsize 0
# my core time is 0.903418
# the processor [3, 1] start...
# res_back start...
# my res time is 0.014229
# process[3, 0] read 0 times and max qsize 0
# my core time is 0.845025
# the processor [3, 2] start...
# res_back start...
# my res time is 0.013756
# the processor [3, 3] start...
# process[3, 1] read 0 times and max qsize 0
# my core time is 0.983533
# the processor [3, 4] start...
# process[3, 2] read 0 times and max qsize 0res_back start...
# my res time is 0.013237
#
# my core time is 1.067643
# the processor [3, 5] start...
# process[3, 3] read 0 times and max qsize 0
# my core time is 0.963421
# res_back start...
# my res time is 0.012993
# the processor [3, 6] start...
# process[3, 4] read 0 times and max qsize 0
# my core time is 0.923525
# res_back start...
# my res time is 0.01408
# the processor [3, 7] start...
# process[3, 5] read 0 times and max qsize 0
# my core time is 0.954395
# res_back start...
# my res time is 0.013251
# res_back start...
# my res time is 0.016991
# process[3, 6] read 0 times and max qsize 0
# my core time is 1.033238
# the processor [4, 0] start...
# res_back start...
# my res time is 0.013321
# process[3, 7] read 0 times and max qsize 0
# my core time is 0.997329
# the processor [4, 1] start...
# res_back start...
# my res time is 0.015694
# process[4, 0] read 0 times and max qsize 0
# my core time is 0.889537
# the processor [4, 2] start...
# res_back start...
# my res time is 0.015733
# the processor [4, 3] start...
# process[4, 1] read 0 times and max qsize 0
# my core time is 0.991871
# the processor [4, 4] start...
# process[4, 2] read 0 times and max qsize 0
# my core time is 1.005075
# res_back start...
# my res time is 0.013204
# process[4, 3] read 0 times and max qsize 0
# my core time is 0.913342
# the processor [4, 5] start...
# res_back start...
# my res time is 0.013704
# res_back start...
# my res time is 0.013963
# the processor [4, 6] start...
# process[4, 4] read 0 times and max qsize 0
# my core time is 0.99047
# process[4, 5] read 0 times and max qsize 0
# my core time is 0.841896
# the processor [4, 7] start...
# res_back start...
# my res time is 0.013666
# res_back start...
# my res time is 0.013258
# the processor [5, 0] start...
# process[4, 6] read 0 times and max qsize 0
# my core time is 0.939569
# the processor [5, 1] start...
# process[4, 7] read 0 times and max qsize 0
# my core time is 0.989868
# res_back start...
# my res time is 0.013967
# process[5, 0] read 0 times and max qsize 0
# my core time is 0.910794
# the processor [5, 2] start...
# res_back start...
# my res time is 0.013616
# res_back start...
# my res time is 0.014418
# process[5, 1] read 0 times and max qsize 0
# my core time is 0.970843
# the processor [5, 3] start...
# the processor [5, 4] start...
# process[5, 2] read 0 times and max qsize 0
# my core time is 0.965431
# res_back start...
# my res time is 0.015266
# the processor [5, 5] start...
# process[5, 3] read 0 times and max qsize 0
# my core time is 0.993859
# res_back start...
# my res time is 0.014967
# the processor [5, 6] start...
# process[5, 4] read 0 times and max qsize 0
# my core time is 1.090765
# res_back start...
# my res time is 0.014403
# process[5, 5] read 0 times and max qsize 0
# my core time is 0.905647
# the processor [5, 7] start...
# res_back start...
# my res time is 0.014015
# the processor [6, 0] start...
# process[5, 6] read 0 times and max qsize 0
# my core time is 1.002522
# res_back start...
# my res time is 0.014551
# the processor [6, 1] start...
# process[5, 7] read 0 times and max qsize 0
# my core time is 1.056189
# res_back start...
# my res time is 0.013948
# the processor [6, 2] start...process[6, 0] read 0 times and max qsize 0
#
# my core time is 0.970235
# res_back start...
# my res time is 0.015618
# the processor [6, 3] start...
# process[6, 1] read 0 times and max qsize 0
# my core time is 1.038742
# res_back start...
# my res time is 0.015411
# the processor [6, 4] start...
# process[6, 2] read 0 times and max qsize 0
# my core time is 1.034519
# res_back start...
# my res time is 0.014253
# the processor [6, 5] start...
# process[6, 3] read 0 times and max qsize 0
# my core time is 0.977464
# res_back start...
# my res time is 0.013778
# the processor [6, 6] start...
# process[6, 4] read 0 times and max qsize 0
# my core time is 0.923747
# res_back start...
# my res time is 0.015815
# the processor [6, 7] start...
# process[6, 5] read 0 times and max qsize 0
# my core time is 0.950678
# res_back start...
# my res time is 0.227229
# the processor [7, 0] start...
# process[6, 6] read 0 times and max qsize 0
# my core time is 0.937969
# res_back start...
# my res time is 0.013099
# res_back start...
# my res time is 0.015436
# the processor [7, 1] start...
# process[6, 7] read 0 times and max qsize 0
# my core time is 1.009184
# the processor [7, 2] start...
# process[7, 0] read 0 times and max qsize 0
# my core time is 0.944816
# res_back start...
# my res time is 0.016347
# res_back start...
# the processor [7, 3] start...
# process[7, 1] read 0 times and max qsize 0
# my core time is 0.959057
# my res time is 0.225585
# res_back start...
# process[7, 2] read 0 times and max qsize 0
# my core time is 0.868046
# the processor [7, 4] start...
# my res time is 0.014249
# res_back start...
# my res time is 0.013796
# the processor [7, 5] start...
# process[7, 3] read 0 times and max qsize 0
# my core time is 0.94493
# process[7, 4] read 0 times and max qsize 0
# my core time is 0.906435
# the processor [7, 6] start...
# res_back start...
# my res time is 0.014631
# res_back start...
# my res time is 0.012795
# process[7, 5] read 0 times and max qsize 0
# my core time is 0.911937
# the processor [7, 7] start...
# res_back start...
# my res time is 0.013105
# process[7, 6] read 0 times and max qsize 0
# my core time is 0.971887
# res_back start...
# my res time is 0.013407
# process[7, 7] read 0 times and max qsize 0
# my core time is 0.969824
# res_back start...
# my res time is 0.013811
# core done!
# Total num of GB sites: 246055
# 080 done
# the processor [0, 0] start...
# the processor [0, 1] start...
# process[0, 0] read 0 times and max qsize 0
# my core time is 0.913984
# the processor [0, 2] start...
# res_back start...
# my res time is 0.059399
# process[0, 1] read 0 times and max qsize 0
# my core time is 0.974764
# the processor [0, 3] start...
# res_back start...
# my res time is 0.014185
# the processor [0, 4] start...
# process[0, 2] read 0 times and max qsize 0
# my core time is 0.968584
# the processor [0, 5] start...
# process[0, 3] read 0 times and max qsize 0
# my core time is 0.916055
# res_back start...
# my res time is 0.019222
# the processor [0, 6] start...
# process[0, 4] read 0 times and max qsize 0
# my core time is 0.965235
# res_back start...
# my res time is 0.015888
# process[0, 5] read 0 times and max qsize 0res_back start...
#
# my core time is 0.984342
# the processor [0, 7] start...
# my res time is 0.257905
# res_back start...
# my res time is 0.016146
# process[0, 6] read 0 times and max qsize 0
# my core time is 0.885113
# the processor [1, 0] start...
# res_back start...
# my res time is 0.018985
# the processor [1, 1] start...
# process[0, 7] read 0 times and max qsize 0
# my core time is 0.944368
# process[1, 0] read 0 times and max qsize 0
# my core time is 0.917146
# the processor [1, 2] start...
# res_back start...
# my res time is 0.02031
# res_back start...
# my res time is 0.017121
# process[1, 1] read 0 times and max qsize 0
# my core time is 0.905868
# the processor [1, 3] start...
# process[1, 2] read 0 times and max qsize 0res_back start...
# my res time is 0.017239
#
# my core time is 0.879093
# the processor [1, 4] start...
# res_back start...
# my res time is 0.016972
# the processor [1, 5] start...
# process[1, 3] read 0 times and max qsize 0
# my core time is 1.006528
# the processor [1, 6] start...
# process[1, 4] read 0 times and max qsize 0
# my core time is 0.986031
# res_back start...
# my res time is 0.017471
# the processor [1, 7] start...
# process[1, 5] read 0 times and max qsize 0
# my core time is 0.973196
# res_back start...
# my res time is 0.017174
# res_back start...
# my res time is 0.032099
# process[1, 6] read 0 times and max qsize 0
# my core time is 1.038846
# the processor [2, 0] start...
# res_back start...
# my res time is 0.0344
# the processor [2, 1] start...
# process[1, 7] read 0 times and max qsize 0
# my core time is 0.989311
# the processor [2, 2] start...
# process[2, 0] read 0 times and max qsize 0
# my core time is 0.958479
# res_back start...
# my res time is 0.017367
# process[2, 1] read 0 times and max qsize 0
# my core time is 0.901904
# the processor [2, 3] start...
# res_back start...
# my res time is 0.017158
# res_back start...
# my res time is 0.01906
# process[2, 2] read 0 times and max qsize 0
# my core time is 0.950068
# the processor [2, 4] start...
# res_back start...
# my res time is 0.016894
# the processor [2, 5] start...
# process[2, 3] read 0 times and max qsize 0
# my core time is 1.014899
# the processor [2, 6] start...
# process[2, 4] read 0 times and max qsize 0
# my core time is 0.892281
# res_back start...
# my res time is 0.018116
# res_back start...
# my res time is 0.017081
# process[2, 5] read 0 times and max qsize 0
# my core time is 0.925287
# the processor [2, 7] start...
# res_back start...
# my res time is 0.017127
# process[2, 6] read 0 times and max qsize 0
# my core time is 0.914329
# the processor [3, 0] start...
# res_back start...
# my res time is 0.018732
# the processor [3, 1] start...
# process[2, 7] read 0 times and max qsize 0
# my core time is 0.979954
# the processor [3, 2] start...
# process[3, 0] read 0 times and max qsize 0
# my core time is 1.053081
# res_back start...
# my res time is 0.018504
# the processor [3, 3] start...
# process[3, 1] read 0 times and max qsize 0
# my core time is 0.931896
# res_back start...
# my res time is 0.019143
# the processor [3, 4] start...
# process[3, 2] read 0 times and max qsize 0
# my core time is 1.092553
# res_back start...
# my res time is 0.017822
# process[3, 3] read 0 times and max qsize 0
# my core time is 0.842016
# the processor [3, 5] start...
# res_back start...
# my res time is 0.017403
# process[3, 4] read 0 times and max qsize 0
# my core time is 0.907815
# the processor [3, 6] start...
# res_back start...
# my res time is 0.018212
# res_back start...
# my res time is 0.017636
# the processor [3, 7] start...
# process[3, 5] read 0 times and max qsize 0
# my core time is 0.988856
# the processor [4, 0] start...
# process[3, 6] read 0 times and max qsize 0
# my core time is 1.023188
# res_back start...
# my res time is 0.01693
# the processor [4, 1] start...
# process[3, 7] read 0 times and max qsize 0
# my core time is 0.966438
# res_back start...
# my res time is 0.015528
# the processor [4, 2] start...
# process[4, 0] read 0 times and max qsize 0
# my core time is 1.011618
# res_back start...
# my res time is 0.017408
# process[4, 1] read 0 times and max qsize 0
# my core time is 0.951322
# the processor [4, 3] start...
# res_back start...
# my res time is 0.017162
# process[4, 2] read 0 times and max qsize 0
# my core time is 0.92481
# the processor [4, 4] start...
# res_back start...
# my res time is 0.221955
# res_back start...
# my res time is 0.015436
# process[4, 3] read 0 times and max qsize 0
# my core time is 0.916477
# the processor [4, 5] start...
# res_back start...
# my res time is 0.01636
# process[4, 4] read 0 times and max qsize 0
# my core time is 0.962735
# the processor [4, 6] start...
# process[4, 5] read 0 times and max qsize 0
# my core time is 0.930201
# the processor [4, 7] start...
# res_back start...
# my res time is 0.021498
# res_back start...
# my res time is 0.017355
# process[4, 6] read 0 times and max qsize 0
# my core time is 0.876394
# the processor [5, 0] start...
# res_back start...
# my res time is 0.014014
# the processor [5, 1] start...
# process[4, 7] read 0 times and max qsize 0
# my core time is 1.022739
# the processor [5, 2] start...
# process[5, 0] read 0 times and max qsize 0res_back start...
# my res time is 0.018319
#
# my core time is 1.058015
# the processor [5, 3] start...
# process[5, 1] read 0 times and max qsize 0
# my core time is 0.991835
# res_back start...
# my res time is 0.014803
# the processor [5, 4] start...
# process[5, 2] read 0 times and max qsize 0
# my core time is 0.94564
# res_back start...
# my res time is 0.015838
# res_back start...
# my res time is 0.014763
# process[5, 3] read 0 times and max qsize 0
# my core time is 0.941699
# the processor [5, 5] start...
# res_back start...
# my res time is 0.014836
# process[5, 4] read 0 times and max qsize 0
# my core time is 0.986375
# the processor [5, 6] start...
# the processor [5, 7] start...
# process[5, 5] read 0 times and max qsize 0
# my core time is 1.04377
# res_back start...
# my res time is 0.014821
# process[5, 6] read 0 times and max qsize 0
# my core time is 0.856047
# the processor [6, 0] start...
# res_back start...
# my res time is 0.019127
# the processor [6, 1] start...
# process[5, 7] read 0 times and max qsize 0
# my core time is 0.971481
# res_back start...
# my res time is 0.017933
# the processor [6, 2] start...
# process[6, 0] read 0 times and max qsize 0
# my core time is 1.043915
# res_back start...
# my res time is 0.017511
# the processor [6, 3] start...
# process[6, 1] read 0 times and max qsize 0
# my core time is 1.001712
# res_back start...
# my res time is 0.014743
# the processor [6, 4] start...
# process[6, 2] read 0 times and max qsize 0
# my core time is 1.009074
# res_back start...
# my res time is 0.014353
# the processor [6, 5] start...
# process[6, 3] read 0 times and max qsize 0
# my core time is 1.063067
# res_back start...
# my res time is 0.243183
# process[6, 4] read 0 times and max qsize 0
# my core time is 0.938874
# the processor [6, 6] start...
# res_back start...
# my res time is 0.014857
# res_back start...
# my res time is 0.016615
# the processor [6, 7] start...
# process[6, 5] read 0 times and max qsize 0
# my core time is 0.969294
# the processor [7, 0] start...
# process[6, 6] read 0 times and max qsize 0
# my core time is 0.934
# res_back start...
# my res time is 0.019316
# the processor [7, 1] start...
# process[6, 7] read 0 times and max qsize 0
# my core time is 1.012337
# res_back start...
# my res time is 0.016095
# the processor [7, 2] start...
# process[7, 0] read 0 times and max qsize 0
# my core time is 0.947304
# res_back start...
# my res time is 0.014596
# the processor [7, 3] start...
# process[7, 1] read 0 times and max qsize 0
# my core time is 0.984572
# res_back start...
# my res time is 0.016433
# res_back start...
# the processor [7, 4] start...
# process[7, 2] read 0 times and max qsize 0
# my core time is 0.977154
# my res time is 0.254401
# res_back start...
# my res time is 0.04165
# process[7, 3] read 0 times and max qsize 0
# my core time is 0.953046
# the processor [7, 5] start...
# res_back start...
# my res time is 0.03045
# the processor [7, 6] start...
# process[7, 4] read 0 times and max qsize 0
# my core time is 0.986753
# the processor [7, 7] start...
# res_back start...
# my res time is 0.038457
# process[7, 5] read 0 times and max qsize 0
# my core time is 0.960187
# res_back start...
# my res time is 0.014794
# process[7, 6] read 0 times and max qsize 0
# my core time is 0.944279
# res_back start...
# my res time is 0.014619
# process[7, 7] read 0 times and max qsize 0
# my core time is 0.964425
# res_back start...
# my res time is 0.014352
# core done!
# Total num of GB sites: 247244
# 090 done

# %%
    expected_grain_num = 1000
    label_list = ["0.7", "0.8", "0.9"]
    ar_data_path_well = f"/well_normal_data/aspect_ratio_Well_grain{expected_grain_num}.npy"
    ar_data_path_cos = f"/well_normal_data/aspect_ratio_Cos_grain{expected_grain_num}.npy"
    ar_data_path_cosmin1 = f"/well_normal_data/aspect_ratio_CosMin1_grain{expected_grain_num}.npy"
    ar_data_path_cosmax1mobility = f"/well_normal_data/aspect_ratio_CosMax1Mobility_grain{expected_grain_num}.npy"

    aniso_rs_well = np.load(current_path+ar_data_path_well)
    aniso_rs_cos = np.load(current_path+ar_data_path_cos)
    aniso_rs_cosmin1 = np.load(current_path+ar_data_path_cosmin1)
    aniso_rs_cosmax1mobility = np.load(current_path+ar_data_path_cosmax1mobility)

    plt.close()
    fig = plt.figure(figsize=(5, 5))
    plt.plot(np.linspace(0,len(label_list)-1,len(label_list)), aniso_rs_well[1:], '.-', markersize=8, linewidth=2,label="Well")
    plt.plot(np.linspace(0,len(label_list)-1,len(label_list)), aniso_rs_cos[1:], '.-', markersize=8, linewidth=2,label=r"Cos-$\gamma_{ave}=1$")
    plt.plot(np.linspace(0,len(label_list)-1,len(label_list)), aniso_rs_cosmin1[1:], '.-', markersize=8, linewidth=2,label=r"Cos-$\gamma_{min}=1$")
    plt.plot(np.linspace(0,len(label_list)-1,len(label_list)), aniso_rs_cosmax1mobility[1:], '.-', markersize=8, linewidth=2,label="Cos-m")
    plt.plot(np.linspace(0,len(label_list)-1,len(label_list)), aniso_rs_well[0]*np.ones(len(label_list)), '--', color='gray',linewidth=2,label="Iso")
    plt.plot(np.linspace(0,len(label_list)-1,len(label_list)), 0.50*np.ones(len(label_list)), '--',color='k',linewidth=2,label="Experiment")
    plt.xlabel(r"$\sigma$", fontsize=16)
    plt.ylabel("Aspect Ratio", fontsize=16)
    plt.xticks(np.linspace(0,len(label_list)-1,len(label_list)),label_list)
    plt.legend(fontsize=13,ncol=2)
    plt.ylim([-0.05,0.9])
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    plt.savefig(current_path + f"/figures/anisotropic_poly_p_20k_aspect_ratio_all_{expected_grain_num}grains.png", dpi=400,bbox_inches='tight')
