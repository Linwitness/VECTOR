# %%
import os
current_path = os.getcwd()
import sys
sys.path.append(current_path)
sys.path.append('./../../.')
import numpy as np
import math
from itertools import repeat
import h5py
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
cos_energy_fraction = [2.255, 0.095, 1.519]
well_energy_fraction = [1.905, 1.013, 1.519]
iso_fraction = [0.0177]
x = np.array([1,2,3])

# %%
plt.figure()
fig = plt.figure(figsize=(7, 7))
xlim = [0,3.5]
bar_width = 0.2
plt.bar(0.2,iso_fraction,width=bar_width,color='grey',edgecolor='grey',label='isotropic')
plt.bar(x-bar_width/2,cos_energy_fraction,width=bar_width,color='C0',edgecolor='grey',label='2D cos energy')
plt.bar(x+bar_width/2,well_energy_fraction,width=bar_width,color='C1',edgecolor='grey',label='2D well energy')
plt.legend(fontsize=18)
plt.xlim(xlim)
plt.xticks([0.2,1,2,3],['Iso','Fully','M-depedent','I-depedent'],fontsize=14)
plt.ylim([0,2.5])
plt.ylabel('Anti-c fraction (%)',fontsize=14)
# Out:
# Text(0, 0.5, 'Anti-c fraction (%)')
